# %% [markdown]
# Exercise

# %%
from pynhd import NLDI, WaterData, NHDPlusHR, GeoConnex
import geopandas as gpd
import pandas as pd
from supporting_scripts import getData, SNOTEL_Analyzer, dataprocessing, mapping
from shapely.geometry import box, Polygon
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 4
#       2 import geopandas as gpd
#       3 import pandas as pd
# ----> 4 from supporting_scripts import getData, SNOTEL_Analyzer, dataprocessing, mapping
#       5 from shapely.geometry import box, Polygon
#       6 import os
#
# ModuleNotFoundError: No module named 'supporting_scripts'

# %%
mamba install pytz
# Out:
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# [+] 0.0s
#
# Pinned packages:
#
#   - python=3.10
#
#
# Transaction
#
#   Prefix: /uufs/chpc.utah.edu/common/home/u1589214/.conda/envs/hyriver
#
#   All requested packages already installed
#
#
# Transaction starting
#
# Transaction finished
#
#
# Note: you may need to restart the kernel to use updated packages.
